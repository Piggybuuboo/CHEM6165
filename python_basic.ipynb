# %%
num = 1

print(type(num))

num = float(num)

print(type(num))
# Out:
# <class 'int'>
# <class 'float'>

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
a = 256

id(a)
# Out:
# 140714189452040

# %%
x = 0.1
print(x)
print('{0:.30f}'.format(x))
# Out:
# 0.1
# 0.100000000000000005551115123126

# %%
x = 1
y = 2.5000

x = int(x)
y = float(y)

print(x+y)
# Out:
# 3.5

# %%
a = 256
b = 256
c = 256 + 1
d = 257

print(c is d)
print(id(c), id(d))

def test():
    x = 257
    y = 256 + 1
    print(x is y)
    print(id(x), id(y))

test()
# Out:
# False
# 1532883711248 1532883710704
# True
# 1532883710192 1532883710192

# %%
Fruit_List = ['Apple', 'Banana', 'Cherry', 'Durian']
print(Fruit_List)
# Out:
# ['Apple', 'Banana', 'Cherry', 'Durian']

# %%
HC_Compound_List = ['Methane', 'Ethane', 'Propane', 'Butane']
HC_Compound_Tuple = ('Methane', 'Ethane', 'Propane', 'Butane')

HC_Compound_List.append('Pentane')
HC_Compound_Tuple.append('Pentane')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       2 HC_Compound_Tuple = ('Methane', 'Ethane', 'Propane', 'Butane')
#       4 HC_Compound_List.append('Pentane')
# ----> 5 HC_Compound_Tuple.append('Pentane')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
mol_sat_list = ["Ethene","Propene"]
mol_unsat_list = ["Ethane"]

mol_dict = {"Sat":mol_sat_list, "Unsat":mol_unsat_list}

print(mol_dict)

print(mol_dict["Sat"])

print(mol_dict["Sat"][1])
print(id(mol_sat_list))
mol_sat_list.append("Ethene")
print(id(mol_sat_list))
mol_dict["Sat"]
# Out:
# {'Sat': ['Ethene', 'Propene'], 'Unsat': ['Ethane']}
# ['Ethene', 'Propene']
# Propene
# 2097426257344
# 2097426257344
# ['Ethene', 'Propene', 'Ethene']

# %%
print('---------')
print(mol_dict["Sat"])
print(id(mol_sat_list))
mol_sat_list = list(set(mol_sat_list))
print(id(mol_sat_list))

print(mol_sat_list)
mol_dict = {"Sat":mol_sat_list, "Unsat":mol_unsat_list}
print(mol_dict["Sat"])
# Out:
# ---------
# ['Ethene', 'Propene', 'Ethene']
# 2097425978176
# 2097426077952
# ['Ethene', 'Propene']
# ['Ethene', 'Propene']

# %%
def sqrt(x):
    '''Take a given number, then power up by 0.5 as square root. If it equals or more than zero, then proceed, if not returns error.'''
    if x >= 0:
        print(x**0.5)
    else:
        print("Error! Negative Number")

sqrt(9)

sqrt(8)

sqrt(0)

sqrt(-2)

print(sqrt)
# Out:
# 3.0
# 2.8284271247461903
# 0.0
# Error! Negative Number
# <function sqrt at 0x000001E8585EA2A0>

# %%
arbitrary_list = ['5', '3', '8', '2', '9', '6']

print(arbitrary_list)

arbitrary_list.sort()

print(arbitrary_list)

arbitrary_list.sort(reverse=True)

print(arbitrary_list)
# Out:
# ['5', '3', '8', '2', '9', '6']
# ['2', '3', '5', '6', '8', '9']
# ['9', '8', '6', '5', '3', '2']
